# %% [markdown]
# ##
#  # File: train.ipynb
#  # Author: Karim Abogharbia
#  # Description: This program imports a data set and based on this dataset it can predict values in between its given values
#  # Date: [27/8/2023]
#  ##

# %% [markdown]
# # Header Files

# %%
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import pandas as pd
# %run "C:\Users\karim\OneDrive\Desktop\VScode Projects\ML implement\LinearRegression.ipynb"

# %% [markdown]
# # Data set is imported

# %%
df = pd.read_csv("shrink_ray_dataset.csv")

# %% [markdown]
# # Data set is split up into test batch and training batch

# %%
X = df.iloc[:, 0]
y = df.iloc[:, 1]
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=1234
)

# %% [markdown]
# # Scatter plot of data set before prediction

# %%
fig = plt.figure(figsize=(8, 6))
plt.scatter(X, y, color="r", marker="o", s=10)
plt.show()

# %% [markdown]
# # Instance of class and predictions are made

# %%
reg = LinearRegression(lr=0.00001)

reg.fit(X_train, y_train)
predictions = reg.predict(X_test)

# %%
def mse(y_test, predictions):
    return np.mean((y_test - predictions) ** 2)

# %% [markdown]
# # The mean squared error is calculated

# %%
meansq = mse(y_test, predictions)
print(meansq)
# lowest mean square error was 8.514250942275202
# Out:
# 10.002699076952535

# %% [markdown]
# # Scatter plot of readings including prediction line

# %%
y_pred_line = reg.predict(X)
cmap = plt.get_cmap("viridis")
fig = plt.figure(figsize=(8, 6))
m1 = plt.scatter(X_train, y_train, color="g", s=10)
m2 = plt.scatter(X_test, y_test, color="b", s=10)
plt.plot(X, y_pred_line, color="black", linewidth=2, label="Prediction")
plt.show()

# %% [markdown]
# # Answer to "If Gru needs to shrink the moon with a percentage 85% where should he adjust the knob?"

# %%
print(reg.invpredict(85))
# Best reading I got was 273.21315469118053 at the lowest mean square error
# Out:
# 276.5314945385835
